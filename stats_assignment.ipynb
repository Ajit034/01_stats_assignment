# %% [markdown]
# # 1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.
#
#
# Qualitative Data:
#
# Qualitative data, also known as categorical data, is non-numerical and is used to describe characteristics or qualities. It can be further divided into two types: nominal and ordinal.
#
# Nominal Data:
#
# Definition: Nominal data consists of categories that do not have a natural order or ranking.
# Examples:
# Types of fruits (e.g., apples, bananas, oranges)
#
# Ordinal Data:
#
# Definition: Ordinal data consists of categories that have a meaningful order or ranking, but the intervals between the ranks are not consistent or defined.
# Examples:
# Customer satisfaction ratings (e.g., very dissatisfied, dissatisfied, neutral, satisfied, very satisfied)
#
# Quantitative Data:
#
# Quantitative data is numerical and can be measured or counted. It is typically divided into two types: interval and ratio.
#
# Interval Data:
#
# Definition: Interval data has meaningful intervals between values but lacks a true zero point. This means that you can add and subtract, but you cannot meaningfully multiply or divide.
# Examples:
# Temperature in Celsius or Fahrenheit (e.g., 20°C is not twice as hot as 10°C)
#
# Ratio Data:
#
# Definition: Ratio data has all the properties of interval data, but it also has a true zero point, allowing for meaningful ratios.
# Examples:
# Weight (e.g., 0 kg means no weight, and 10 kg is twice as heavy as 5 kg)

# %% [markdown]
# # 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median,and mode with examples and situations where each is appropriate.
#
# 1. Mean
# Definition: The mean is the arithmetic average of a set of values. It is calculated by summing all the values and dividing by the number of values.
#
# Formula:
# Mean
# =
# ∑
# 𝑋
# 𝑁
# Mean=
# N
# ∑X
# ​
#   (where
# 𝑋
# X represents each value and
# 𝑁
# N is the number of values)
#
# Example:
#
# Dataset: 3, 5, 7, 10
# Mean = (3 + 5 + 7 + 10) / 4 = 6.25
#
# When to Use:
#
# The mean is most appropriate for datasets that are symmetrical and without outliers. It is sensitive to extreme values, which can skew the average.
#
# 2. Median
# Definition: The median is the middle value in a dataset when it is ordered from smallest to largest. If there is an even number of observations, the median is the average of the two middle values.
#
# Example:
#
# Dataset (odd number): 3, 5, 7, 10, 12 → Median = 7
# Dataset (even number): 3, 5, 7, 10 → Median = (5 + 7) / 2 = 6
# When to Use:
#
# The median is useful for skewed distributions or datasets with outliers, as it is not affected by extreme values.
#
#
# 3. Mode
# Definition: The mode is the value that appears most frequently in a dataset. A dataset can have one mode, more than one mode (bimodal or multimodal), or no mode at all if no number repeats.
#
# Example:
#
# Dataset: 2, 4, 4, 6, 7 → Mode = 4
# Dataset: 1, 1, 2, 2, 3 → Modes = 1 and 2 (bimodal)
# When to Use:
#
# The mode is particularly useful for categorical data, where we want to know which category is the most common.

# %% [markdown]
# # 3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#
# Dispersion refers to the degree to which data points in a dataset are spread out or clustered together. Understanding dispersion is crucial because it provides insight into the variability of the data, which can influence the interpretation of measures of central tendency (like the mean or median).
#
# Key Concepts of Dispersion
# Dispersion helps answer questions such as:
#
# How similar or different are the data points from each other?
# Are most data points close to the average, or is there a wide range of values?
#
# Common Measures of Dispersion:
#
# Two of the most common measures of dispersion are variance and standard deviation. Both quantify how much the data points deviate from the mean, but they do so in slightly different ways.
#
# 1. Variance
# Definition: Variance is the average of the squared differences between each data point and the mean. It indicates how far the values in a dataset are spread out from the mean.
#
# Interpretation: A higher variance indicates that the data points are more spread out from the mean, while a lower variance indicates that they are closer to the mean.
# 2. Standard Deviation
# Definition: The standard deviation is the square root of the variance. It provides a measure of dispersion in the same units as the original data, making it more interpretable.
#
# Interpretation: Like variance, a higher standard deviation means the data points are more spread out, while a lower standard deviation means they are more clustered around the mean. Because standard deviation is in the same units as the data, it is often easier to interpret.

# %% [markdown]
# # 4. What is a box plot, and what can it tell you about the distribution of data?
#
# A box plot (or box-and-whisker plot) is a graphical representation of a dataset that summarizes its central tendency, dispersion, and potential outliers. It provides a visual summary of key statistics, allowing for quick comparisons between distributions.
#
# Components of a Box Plot
# A box plot typically consists of the following elements:
#
# Box:
#
# The central box represents the interquartile range (IQR), which contains the middle 50% of the data. It stretches from the first quartile (Q1) to the third quartile (Q3).
# Q1 (25th percentile) is the value below which 25% of the data falls.
# Q3 (75th percentile) is the value below which 75% of the data falls.
# Median:
#
# A line within the box indicates the median (the 50th percentile), which divides the dataset into two equal halves.
# Whiskers:
#
# The "whiskers" extend from the box to the smallest and largest values within 1.5 times the IQR from the quartiles. This helps in identifying the range of the bulk of the data.
# Outliers:
#
# Points outside the whiskers are considered outliers. These are individual data points that fall outside the established range and may indicate variability or unusual occurrences in the dataset.
# What a Box Plot Tells You
# Central Tendency:
#
# The median line within the box provides a quick visual indication of the dataset's central value.
# Spread of Data:
#
# The width of the box (IQR) indicates how spread out the middle 50% of the data is. A wider box suggests greater variability, while a narrower box suggests less variability.
# Skewness:
#
# The position of the median line within the box can indicate skewness. If the median is closer to Q1, the data may be positively skewed (long tail on the right). If it's closer to Q3, it may be negatively skewed (long tail on the left).
# Range and Outliers:
#
# The whiskers show the range of the bulk of the data, while points outside the whiskers indicate outliers, which may need further investigation.
# Example Interpretation
# Consider a box plot for the test scores of two different classes:
#
# Class A: The box is centered with a median around 75, an IQR from 70 to 80, and whiskers extending to 60 and 90. There are no outliers.
# Class B: The box is skewed to the right, with a median around 65, an IQR from 60 to 70, and whiskers extending to 50 and 80. There are several outliers at 85 and 90.
# Interpretation:
#
# Class A has a higher median score and less variability in scores, indicating more consistent performance.
# Class B has a lower median and some outliers, suggesting a wider range of scores and possibly some students performing significantly better than the rest.

# %% [markdown]
# # 5. Discuss the role of random sampling in making inferences about populations.
#
# Random sampling is a fundamental technique in statistics that plays a crucial role in making inferences about populations. By selecting a subset of individuals from a larger population in a way that each individual has an equal chance of being chosen, researchers can draw conclusions that are more likely to be representative of the whole population. Here’s a breakdown of its significance and the implications for statistical inference:
#
# Importance of Random Sampling
# Reduces Bias:
#
# Random sampling helps to eliminate selection bias, ensuring that the sample reflects the diversity and characteristics of the entire population. This enhances the validity of the inferences made from the sample data.
# Improves Generalizability:
#
# By obtaining a representative sample, researchers can generalize their findings to the broader population with greater confidence. This means that conclusions drawn from the sample data are more likely to apply to the entire group.
# Facilitates Statistical Analysis:
#
# Many statistical methods, including hypothesis testing and confidence intervals, rely on the assumption that the data comes from a random sample. Random sampling allows researchers to apply these methods appropriately and interpret the results correctly.
# Enables Estimation of Sampling Error:
#
# Random sampling allows researchers to estimate the variability or error associated with the sample. This is essential for understanding the precision of the estimates and for constructing confidence intervals around those estimates.
# Making Inferences About Populations
# When researchers use random sampling to collect data, they can perform statistical analyses to make inferences about the population. Here's how this process works:
#
# Collecting Data:
#
# A random sample is drawn from the population, and relevant data is collected. For example, a survey of public opinion on a policy might randomly sample 1,000 voters from a population of 1 million.
# Analyzing Sample Data:
#
# Statistical techniques are applied to the sample data to calculate estimates (like means or proportions) and assess variability (like standard deviation).
# Making Inferences:
#
# Based on the sample results, researchers can make inferences about the population. For instance, if the sample reveals that 60% of respondents support a policy, researchers might infer that approximately 60% of the entire population supports it.
# Estimating Confidence Intervals:
#
# Researchers can also calculate confidence intervals to express the uncertainty around their estimates. For example, they might say they are 95% confident that the true proportion of support in the population lies between 57% and 63%.
# Hypothesis Testing:
#
# Random samples allow for hypothesis testing, where researchers can test assumptions about the population based on sample data. For example, testing whether a new teaching method leads to better student performance compared to a traditional method.

# %% [markdown]
# # 6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
#
# Skewness is a statistical measure that describes the asymmetry of a distribution. It indicates the direction and degree to which a dataset deviates from a normal distribution, which is symmetrical. Understanding skewness is important for interpreting data, as it can influence the choice of statistical methods and the conclusions drawn from analyses.
#
# Types of Skewness
# Positive Skewness (Right Skewed):
#
# Definition: A distribution is positively skewed when the right tail (higher values) is longer or fatter than the left tail (lower values).
# Characteristics:
# The mean is typically greater than the median, as extreme high values pull the average up.
# Most of the data points are concentrated on the left side of the distribution.
# Example: Income distribution is often right-skewed, where a few individuals have very high incomes, pulling the mean up while the majority earn less.
# Negative Skewness (Left Skewed):
#
# Definition: A distribution is negatively skewed when the left tail (lower values) is longer or fatter than the right tail (higher values).
# Characteristics:
# The mean is usually less than the median, as extreme low values pull the average down.
# Most data points are concentrated on the right side of the distribution.
# Example: Age at retirement may show left skewness, where most individuals retire around a typical age, but a few retire significantly earlier.
# Zero Skewness (Symmetrical):
#
# Definition: A distribution with zero skewness is perfectly symmetrical, resembling a normal distribution.
# Characteristics:
# The mean and median are equal, and the data is evenly distributed around the center.
# Example: A dataset with a uniform distribution (e.g., rolling a fair die) may exhibit zero skewness.
# Effects of Skewness on Data Interpretation
# Impact on Central Tendency:
#
# Mean and Median: In skewed distributions, the mean can be misleading. For positive skewness, the mean is pulled to the right, while in negative skewness, it is pulled to the left. Relying solely on the mean can misrepresent the "typical" value in the dataset. The median often provides a better measure of central tendency in such cases.
# Choice of Statistical Methods:
#
# Many statistical tests (like t-tests and ANOVA) assume normality. Skewed data can violate these assumptions, leading to incorrect conclusions. Researchers may need to apply transformations (like logarithmic or square root transformations) to achieve normality or use non-parametric methods that do not assume a specific distribution.
# Interpretation of Variability:
#
# Skewness affects the interpretation of variability in the dataset. In a skewed distribution, the range and standard deviation can be influenced more by extreme values, potentially leading to a misunderstanding of the dataset's consistency or reliability.
# Visualization:
#
# Skewness can be visually assessed using histograms or box plots. Identifying skewness helps analysts quickly understand the nature of the data and its potential implications for analysis.

# %% [markdown]
# # 7. What is the interquartile range (IQR), and how is it used to detect outliers?
#
# The interquartile range (IQR) is a measure of statistical dispersion that represents the range within which the middle 50% of a dataset falls. It is calculated as the difference between the third quartile (Q3) and the first quartile (Q1):
#
#
# IQR=Q3−Q1
#
#
# Components of IQR
# First Quartile (Q1): The value below which 25% of the data points fall. It marks the 25th percentile of the dataset.
# Third Quartile (Q3): The value below which 75% of the data points fall. It marks the 75th percentile of the dataset.
# Importance of IQR
# The IQR is a robust measure of variability, particularly useful because it is not affected by extreme values or outliers, making it a preferred method for understanding the spread of a dataset.
#
# Using IQR to Detect Outliers
# The IQR is instrumental in identifying outliers in a dataset. Here’s how it works:
#
# Calculate Q1 and Q3:
#
# Determine the first and third quartiles of the dataset.
# Compute the IQR:
#
# Subtract Q1 from Q3 to find the IQR.
# Determine the Outlier Boundaries:
#
# Outliers can be detected using the following thresholds:
# Lower Boundary:
# IQR=Q1−1.5×IQR
#
#
#
# Upper Boundary:
#
# IQR=Q3+1.5×IQR
#
# Identify Outliers:
#
# Any data points that fall below the lower boundary or above the upper boundary are considered outliers.
#
# Example
# Consider the following dataset:
# Data: 3, 7, 8, 5, 12, 14, 21, 18, 9
#
# Order the Data:
# 3, 5, 7, 8, 9, 12, 14, 18, 21
#
# Calculate Q1 and Q3:
#
# Q1 (25th percentile) = 7 (the median of the first half: 3, 5, 7, 8)
# Q3 (75th percentile) = 14 (the median of the second half: 12, 14, 18, 21)
# Compute the IQR:
#
#
# IQR=Q3−Q1=14−7=7
# Determine Outlier Boundaries:
#
# Lower Boundary:
#
#
# Q1−1.5×IQR=7−1.5×7=7−10.5=−3.5
# Upper Boundary:
#
#
#
# Q3+1.5×IQR=14+1.5×7=14+10.5=24.5
# Identify Outliers:
#
# Any data points below -3.5 or above 24.5 are considered outliers. In this case, there are no outliers in the dataset.

# %% [markdown]
# # 8. Discuss the conditions under which the binomial distribution is used.
# The binomial distribution is a discrete probability distribution that describes the number of successes in a fixed number of independent Bernoulli trials (experiments with two possible outcomes). It is commonly used in situations where the outcomes are binary (e.g., success/failure, yes/no, true/false). Here are the key conditions under which the binomial distribution is appropriate:
#
# Conditions for Using the Binomial Distribution
# Fixed Number of Trials (n):
#
# The experiment consists of a predetermined number of trials, denoted by
# 𝑛
# n. This means that the number of times the experiment is conducted is set in advance.
# Two Possible Outcomes:
#
# Each trial must result in one of two outcomes: a "success" or a "failure." For example, flipping a coin can result in heads (success) or tails (failure).
# Constant Probability of Success (p):
#
# The probability of success, denoted by
# 𝑝
# p, must remain constant for each trial. This means that the chance of success does not change from one trial to another. The probability of failure is
#
# q=1−p.
# Independence of Trials:
#
# The trials must be independent of each other. The outcome of one trial does not affect the outcome of another. For example, the result of one coin flip does not influence the result of the next flip.
# Examples of Binomial Distribution
# Coin Tossing:
#
# If you flip a coin 10 times (fixed number of trials), you can use the binomial distribution to find the probability of getting a specific number of heads (successes).
# Quality Control:
#
# In a manufacturing process, if you inspect 50 items (fixed trials) and want to know the probability that exactly 5 items are defective (successes), you can use the binomial distribution.
# Survey Responses:
#
# If you conduct a survey with 100 participants (fixed trials) and want to know how many say they support a particular candidate (successes), assuming a constant probability of support, the binomial distribution applies.

# %% [markdown]
# # 9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
#
# The normal distribution is a fundamental concept in statistics and probability, characterized by its symmetric, bell-shaped curve. It plays a crucial role in many statistical methods and inference due to its natural occurrence in various phenomena.
#
# Properties of the Normal Distribution
# Symmetry:
#
# The normal distribution is symmetric around its mean. This means that the left half of the distribution is a mirror image of the right half.
# Mean, Median, and Mode:
#
# In a normal distribution, the mean, median, and mode are all equal and located at the center of the distribution.
# Bell Shape:
#
# The curve of the normal distribution is bell-shaped, with the highest point at the mean. The tails of the curve approach, but never actually touch, the horizontal axis, extending infinitely in both directions.
# Defined by Mean and Standard Deviation:
#
# The shape and location of a normal distribution are determined by its mean (
# 𝜇
# μ) and standard deviation (
# 𝜎
# σ).
# The mean (
# 𝜇
# μ) determines the center of the distribution.
# The standard deviation (
# 𝜎
# σ) determines the spread or width of the distribution. A smaller standard deviation results in a steeper curve, while a larger standard deviation results in a flatter curve.
# Total Area Under the Curve:
#
# The total area under the normal distribution curve is equal to 1, representing the entirety of the probability.
# Asymptotic:
#
# The tails of the normal distribution approach the horizontal axis but never actually reach it. This means there is always a non-zero probability for extreme values, no matter how far they are from the mean.
# The Empirical Rule (68-95-99.7 Rule)
# The empirical rule describes how data is distributed in a normal distribution in relation to the mean and standard deviation. It states that:
#
# 68% of the Data:
#
# Approximately 68% of the data points fall within one standard deviation (
# 𝜇
# ±
# 𝜎
# μ±σ) from the mean. This means that if you take a normal distribution and look at the range from one standard deviation below the mean to one standard deviation above the mean, about two-thirds of the observations will lie within this interval.
# 95% of the Data:
#
# Approximately 95% of the data points fall within two standard deviations (
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ) from the mean. This indicates that nearly all data points will be found in the range from two standard deviations below the mean to two standard deviations above the mean.
# 99.7% of the Data:
#
# Approximately 99.7% of the data points fall within three standard deviations (
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ) from the mean. This means that nearly all values in the dataset are captured within this range.
# Visual Representation
# If you were to graph a normal distribution:
#
# The center peak represents the mean.
# The first section (one standard deviation from the mean) captures about 68% of the area.
# The second section (two standard deviations) captures about 95%.
# The third section (three standard deviations) captures about 99.7%.

# %% [markdown]
# # 10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
#
# A Poisson process is a statistical model that describes events occurring randomly and independently over a fixed period of time or space. It is characterized by a constant average rate (λ) at which these events happen.
#
# Real-Life Example: Call Center
# Consider a call center that receives an average of 10 calls per hour. We can model the number of calls received in a given hour as a Poisson process, where:
#
#
#
# λ=10 (the average rate of calls per hour).
#
#
# Specific Event
# Let’s calculate the probability of receiving exactly 5 calls in one hour.
#
# The probability of observing
# 𝑘
# k events in a Poisson process can be calculated using the Poisson probability formula:
#
#
# P(X=k)= e**-a*a**k/k!
#
# Where:
#
#
# P(X=k) is the probability of observing
# 𝑘
# k events.
# 𝑒
# e is Euler's number (approximately 2.71828).
#
# a is the average number of events (in this case, 10).
# 𝑘
# k is the number of events we want to find the probability for (in this case, 5).
# 𝑘
# !
# k! is the factorial of
# 𝑘
# k.

# %% [markdown]
# # 11. Explain what a random variable is and differentiate between discrete and continuous random variables.
# A random variable is a variable that takes on different numerical values, each associated with a specific probability, as a result of a random phenomenon or process. Random variables are fundamental in probability theory and statistics, as they allow us to quantify uncertainty and model random events.
#
# Types of Random Variables
# Random variables can be classified into two main categories: discrete random variables and continuous random variables.
#
# 1. Discrete Random Variables
# Definition: A discrete random variable is one that can take on a countable number of distinct values. This means that the values can be listed out, even if the list is infinite (e.g., the set of all integers).
#
# Examples:
#
# The number of heads obtained when flipping a coin three times (possible values: 0, 1, 2, or 3).
# The number of students in a classroom (can be 0, 1, 2, …, up to the total number of students).
# The outcome of rolling a six-sided die (possible values: 1, 2, 3, 4, 5, or 6).
# Probability Distribution: Discrete random variables are described using a probability mass function (PMF), which gives the probability of each possible value. For example, if
# 𝑋
# X is the number of heads in three flips of a coin, the PMF can specify the probability for
#
# P(X=0),
#
# P(X=1), and so forth.
#
# 2. Continuous Random Variables
# Definition: A continuous random variable is one that can take on an infinite number of possible values within a given range. These values are not countable and can be any value on a continuum, such as all real numbers within an interval.
#
# Examples:
#
# The height of individuals in a population (can take on any value within a range, e.g., 150.5 cm, 150.6 cm, etc.).
# The time taken to run a marathon (can vary continuously, e.g., 2 hours, 2 hours 1 minute, etc.).
# The temperature in a city over a day (can take on any real number value within a reasonable range).
# Probability Distribution: Continuous random variables are described using a probability density function (PDF). Instead of providing probabilities for specific values (which is zero for continuous variables), the PDF gives the probability density, and probabilities are computed over intervals. For example, the probability that a continuous random variable
# 𝑌
# Y falls between two values
# 𝑎
# a and
# 𝑏
# b is given by:
#
# P(a<Y<b)=∫ fY(y)dy
# Summary of Differences
# Feature	Discrete Random Variables	Continuous Random Variables
# Values	Countable, distinct values	Uncountable, infinite values
# Examples	Number of students, die rolls	Height, weight, temperature
# Probability Function	Probability mass function (PMF)	Probability density function (PDF)
# Probability of a Single Value	Can be greater than zero	Always zero (must use intervals)
# Probability Calculation
#
# P(X=k) (specific values)
# 𝑃
# (
# 𝑎
# <
# 𝑌
# <
# 𝑏
# )
# P(a<Y<b) (intervals)

# %% [markdown]
# # 12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
#
# Example Dataset
# Student	Math Score (X)	Science Score (Y)
# 1	85	90
# 2	78	80
# 3	92	95
# 4	88	85
# 5	76	70
#
# X=[85,78,92,88,76]
# Y=[90,80,95,85,70]
# Step 1: Calculate the Mean of X and Y
# First, we calculate the means of the Math and Science scores.
# import numpy as np
#
# np.mean(X)=83.8
# np.mean(Y)=84
#
# Now, calculate the covariance:
#
#
# Cov(X,Y)= 234/5
#         =46.8
# Calculate the Correlation
# Correlation is a standardized measure of the relationship between two variables. The formula for the correlation coefficient
# 𝑟
# r is:
#
# r=cov(X,Y)/sXsY
#
# Now, calculate the correlation coefficient:
# r=0.905
#
# Interpretation of Results
# Covariance:
#
# The covariance of 46.8 indicates a positive relationship between Math and Science scores. This means that as students score higher in Math, they also tend to score higher in Science. However, the covariance value alone does not indicate the strength of the relationship.
# Correlation:
#
# The correlation coefficient
# 𝑟
# ≈
# 0.905
# r≈0.905 indicates a strong positive linear relationship between Math and Science scores. A value close to 1 suggests that the two variables move in the same direction and that knowing a student's Math score can give us a good indication of their Science score.
